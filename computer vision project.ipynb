# %%
#Karishma sajjad
#computer vision project
# flipping, cropping and copying images

# %%
#importing libraries
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
#loading image
img = plt.imread('C:/Users/Karishma Sajjad/Downloads/me.JPG')

# %%
plt.imshow(img)

# %%
#copying image
import cv2
import numpy as np

image= cv2.imread('C:/Users/Karishma Sajjad/Downloads/me.JPG')

imagecopy= np.copy(image)

cv2.imshow('C:/Users/Karishma Sajjad/Downloads/me.JPG', imagecopy)

# %%
#flipping image
from PIL import Image
imageObject = Image.open('C:/Users/Karishma Sajjad/Downloads/me.JPG')
hori_flippedImage = imageObject.transpose(Image.FLIP_LEFT_RIGHT)

imageObject.show()

hori_flippedImage.show()

# %%
#cropping image
img = Image.open('C:/Users/Karishma Sajjad/Downloads/me.JPG')
img.show()

# %%
box = (250, 250, 750, 750)
img2 = img.crop(box)

# %%
img2.save('me_cropped.jpg')
img2.show()

# %%
import cv2
image = cv2.imread('C:/Users/Karishma Sajjad/Downloads/me.JPG')

y=0
x=0
h=300
w=510
crop_image = image[x:w, y:h]
cv2.imshow("Cropped", crop_image)
cv2.waitKey(0)
# Out:
# -1
